# %%
from tensor import Tensor

data = [[0, 1, 2], [0, 0, 0]]
tensor = Tensor(data)
type(tensor)
# Out:
# Tensor created successfully
# Tensor information:
# Number of dimensions: 2
# Shape: [2, 3]
# Data:
# [0, 1, 2, 0, 0, 0]
# tensor.Tensor

# %%
from tensor import Tensor
import time

ini = time.time()
a = Tensor([10000*[1, 2, 3]])
fim = time.time()

print(fim-ini)
# Out:
# Tensor created successfully
# Tensor information:
# Number of dimensions: 2
# Shape: [1, 30000]
# Data:
# ...

# %%
c= a+b
# Out:
# 2
# ndim 2
# ndim 2
#
#
# num elements 0Tensor created successfully
# Tensor information:
# Number of dimensions: 2
# Shape: [0, 0]
# Data:
# []
# ---------------------------------------------------------------------------
# ArgumentError                             Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 c= a+b
#
# File ~/Documentos/recreate_pytorch/foo/python/tensor.py:68, in Tensor.__add__(self, other)
#      65 print(int(self.tensor.contents.ndim))
#      67 result_tensor_data_ptr = self.lib.add(self.tensor, other.tensor)
# ---> 68 ptr_value = ctypes.cast(self.tensor.contents, ctypes.POINTER(ctypes.c_int)).contents.value
#      70 # Now 'ptr_value' contains the integer value
#      71 print(ptr_value, "kkkkk")
#
# File /usr/lib/python3.9/ctypes/__init__.py:510, in cast(obj, typ)
#     509 def cast(obj, typ):
# --> 510     return _cast(obj, obj, typ)
#
# ArgumentError: argument 1: <class 'TypeError'>: wrong type
